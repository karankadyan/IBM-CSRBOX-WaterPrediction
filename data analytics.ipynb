# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv("waterQuality1.csv")

# %%
df.head()
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# ...

# %%
df.tail()
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 7994       0.05    7.78     0.00    1.95     0.04        0.10      0.03
# 7995       0.05   24.22     0.02    0.59     0.01        0.45      0.02
# 7996       0.09    6.85     0.00    0.61     0.03        0.05      0.05
# 7997       0.01      10     0.01    2.00     0.00        2.00      0.00
# 7998       0.04    6.85     0.01    0.70     0.03        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# 7994    0.03      1.37       0.0  ...  0.197     14.29       1.0    0.005
# 7995    0.02      1.48       0.0  ...  0.031     10.27       1.0    0.001
# 7996    0.02      0.91       0.0  ...  0.182     15.92       1.0    0.000
# 7997    0.09      0.00       0.0  ...  0.000      0.00       0.0    0.000
# 7998    0.03      1.00       0.0  ...  0.182     15.92       1.0    0.000
#
#       perchlorate  radium  selenium  silver  uranium  is_safe
# ...

# %% [markdown]
# # Sanity check of data

# %% [markdown]
# Here we will identifying the missing values, outliers or garbage values that are present in our code.
# To gain better accuracy, we have to remove those values.

# %%
df.shape
# Out:
# (7999, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
# ...

# %%
# finding the missing values
df.isnull().sum()
# Out:
# aluminium      0
# ammonia        0
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        0
# dtype: int64

# %%
# finding the percentage of missing values
df.isnull().sum()/df.shape[0]*100
# Out:
# aluminium      0.0
# ammonia        0.0
# arsenic        0.0
# barium         0.0
# cadmium        0.0
# chloramine     0.0
# chromium       0.0
# copper         0.0
# flouride       0.0
# bacteria       0.0
# viruses        0.0
# lead           0.0
# nitrates       0.0
# nitrites       0.0
# mercury        0.0
# perchlorate    0.0
# radium         0.0
# selenium       0.0
# silver         0.0
# uranium        0.0
# is_safe        0.0
# dtype: float64

# %%
# finding the duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
# descriptive statistics
df.describe().T
# Out:
#               count       mean        std  min    25%    50%     75%    max
# aluminium    7999.0   0.666158   1.265145  0.0  0.040  0.070   0.280   5.05
# arsenic      7999.0   0.161445   0.252590  0.0  0.030  0.050   0.100   1.05
# barium       7999.0   1.567715   1.216091  0.0  0.560  1.190   2.480   4.94
# cadmium      7999.0   0.042806   0.036049  0.0  0.008  0.040   0.070   0.13
# chloramine   7999.0   2.176831   2.567027  0.0  0.100  0.530   4.240   8.68
# chromium     7999.0   0.247226   0.270640  0.0  0.050  0.090   0.440   0.90
# copper       7999.0   0.805857   0.653539  0.0  0.090  0.750   1.390   2.00
# flouride     7999.0   0.771565   0.435373  0.0  0.405  0.770   1.160   1.50
# bacteria     7999.0   0.319665   0.329485  0.0  0.000  0.220   0.610   1.00
# viruses      7999.0   0.328583   0.378096  0.0  0.002  0.008   0.700   1.00
# lead         7999.0   0.099450   0.058172  0.0  0.048  0.102   0.151   0.20
# ...

# %%
# Histogram to understand the distribution
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
# Plotting null values on heatmap
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# Boxplot to identify Outliers
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
# Scatter plot to understand the relationship
for i in ['aluminium', 'arsenic', 'barium', 'cadmium', 'chloramine', 'chromium',
       'copper', 'flouride', 'bacteria', 'viruses', 'lead', 'nitrates',
       'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium', 'silver',
       'uranium']:
    sns.scatterplot(data=df,x=i,y='bacteria')
    plt.show()

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['aluminium', 'arsenic', 'barium', 'cadmium', 'chloramine', 'chromium',
#        'copper', 'flouride', 'bacteria', 'viruses', 'lead', 'nitrates',
#        'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium', 'silver',
#        'uranium'],
#       dtype='object')

# %%
# correlation to interpret the relation and multicolliniarity
s = df.select_dtypes(include="number").corr()
s
# Out:
#              aluminium   arsenic    barium   cadmium  chloramine  chromium  \
# aluminium     1.000000  0.225773  0.294145 -0.099911    0.369309  0.353218
# arsenic       0.225773  1.000000  0.362945  0.334682    0.356559  0.312475
# barium        0.294145  0.362945  1.000000 -0.037803    0.446928  0.415972
# cadmium      -0.099911  0.334682 -0.037803  1.000000   -0.144370 -0.157766
# chloramine    0.369309  0.356559  0.446928 -0.144370    1.000000  0.555938
# chromium      0.353218  0.312475  0.415972 -0.157766    0.555938  1.000000
# copper        0.168612 -0.036444  0.065426 -0.109024    0.119059  0.113043
# flouride     -0.009784  0.003792 -0.018548  0.004880    0.004400 -0.002284
# bacteria     -0.078238  0.035688  0.101259 -0.092431    0.154510  0.142041
# viruses      -0.070863  0.011703 -0.002276  0.021183    0.003687  0.002430
# lead          0.020792 -0.087756 -0.042888 -0.034959   -0.030479 -0.050501
# ...

# %%
# correlation with heatmap to interpret the relation and multicolliniarity
plt.figure(figsize=(16,16))
sns.heatmap(s, annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
columns = ['aluminium', 'arsenic', 'barium', 'cadmium', 'chloramine', 'chromium',
       'copper', 'flouride', 'bacteria', 'viruses', 'lead', 'nitrates',
       'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium', 'silver',
       'uranium']

# Loop through each column and plot the density plot
for col in columns:
    sns.distplot(a=df[col], hist=False)
    plt.title(f'Density plot for {col}')
    plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(x=df['bacteria'], 
                y=df['is_safe'])
# Out:
# <Axes: xlabel='bacteria', ylabel='is_safe'>

# %%
sns.scatterplot(x=df['viruses'], 
                y=df['is_safe'])
# Out:
# <Axes: xlabel='viruses', ylabel='is_safe'>

# %% [markdown]
# # Correlation matrix

# %%
matrix = np.corrcoef(df['arsenic'], df['bacteria'])
print(matrix)
# Out:
# [[1.         0.03568844]
#  [0.03568844 1.        ]]

# %% [markdown]
# # Contigency Table

# %%
from scipy.stats import chi2_contingency

# Discretize 'chromium' for creating a contingency table
df['chromium_category'] = pd.cut(df['chromium'], bins=3, labels=['low', 'medium', 'high'])

# Create a contingency table
contingency_table = pd.crosstab(df['chromium_category'], df['is_safe'])
contingency_table
# Out:
# is_safe            #NUM!     0    1
# chromium_category
# low                    3  4987  402
# medium                 0  1056  268
# high                   0  1041  242

# %% [markdown]
# # Performing Chi-Square test

# %%
from scipy.stats import chi2_contingency

# Perform chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

chi2, p, dof, expected
# Out:
# (257.4347705084939,
#  1.6283510741171505e-54,
#  4,
#  array([[2.02225278e+00, 4.77521290e+03, 6.14764846e+02],
#         [4.96562070e-01, 1.17254857e+03, 1.50954869e+02],
#         [4.81185148e-01, 1.13623853e+03, 1.46280285e+02]]))

# %% [markdown]
# # Performing t-test

# %%
import pandas as pd
from scipy.stats import ttest_1samp, ttest_ind

numeric_columns = ['aluminium', 'arsenic', 'barium', 'cadmium', 'chloramine', 'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead', 'nitrates', 'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium', 'silver', 'uranium']

# One-sample t-test
for col in numeric_columns:
    t_stat, p_value = ttest_1samp(df[col], popmean=0)  # Replace 0 with your hypothesized value
    print(f"{col}: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}")
# Out:
# aluminium: t-statistic = 47.0928, p-value = 0.0000
# arsenic: t-statistic = 57.1644, p-value = 0.0000
# barium: t-statistic = 115.2972, p-value = 0.0000
# cadmium: t-statistic = 106.2002, p-value = 0.0000
# chloramine: t-statistic = 75.8424, p-value = 0.0000
# chromium: t-statistic = 81.6995, p-value = 0.0000
# copper: t-statistic = 110.2819, p-value = 0.0000
# flouride: t-statistic = 158.5000, p-value = 0.0000
# bacteria: t-statistic = 86.7714, p-value = 0.0000
# viruses: t-statistic = 77.7250, p-value = 0.0000
# lead: t-statistic = 152.9002, p-value = 0.0000
# nitrates: t-statistic = 158.4759, p-value = 0.0000
# nitrites: t-statistic = 207.5085, p-value = 0.0000
# mercury: t-statistic = 156.5506, p-value = 0.0000
# perchlorate: t-statistic = 83.2319, p-value = 0.0000
# radium: t-statistic = 112.4427, p-value = 0.0000
# selenium: t-statistic = 154.4558, p-value = 0.0000
# silver: t-statistic = 92.0725, p-value = 0.0000
# uranium: t-statistic = 148.5074, p-value = 0.0000
